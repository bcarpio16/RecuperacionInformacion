# %% [markdown]
# # Ejercicio 12: Web Scraping
# ## Objetivo de la práctica
# El objetivo de este ejercicio es construir un web scraper que recoja datos de un website.

# %% [markdown]
# ## Parte 0: Planificar
#
# 1. Identificar los datos que quieres obtener.
# 2. Elegir el sitio web objetivo.
# 3. Planificar la estructura del corpus.

# %% [markdown]
# # Parte 1: Entender el sitio web objetivo
#
# * Analizar la estructura de la página web a ser analizada.
# * Identificar los elementos HTML que contienen los datos bsuscados.

# %%
# RAG
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 55.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0.post1

# %%
import openai
import faiss
import pandas as pd
from bs4 import BeautifulSoup
from IPython.display import Image, display
from sentence_transformers import SentenceTransformer
import os
import requests
import numpy as np
# Out:
# 2025-07-27 20:31:40.209225: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753648300.411417      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753648300.472029      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#Open AI 

import os
from openai import OpenAI

#Obtenemos el secret_key
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("key") 

# Inicializamos el cliente de OpenAI
client = OpenAI(api_key=api_key)

# Creamos la petición al modelo GPT
response = client.responses.create(
    model="gpt-4o",
    #model="gpt-4.1",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# Under the silvery glow of the moon, Luna the unicorn softly trotted across the stardust-kissed meadows, weaving dreams of wonder for all the sleeping children.

# %%
file = "/kaggle/input/recetas/rotisserie-chicken.html"

#Cargamos el archivo html
with open(file, "r", encoding='utf-8') as file:
    html_content = file.read()

#Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")

# %%
# Extracting the recipe title
title = soup.find("meta", {"property": "og:title"})["content"]
title
# Out:
# 'Rotisserie Chicken'

# %%
#Ingredientes 
ingredients_section = soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")
for ingredient in ingredients_section:
    print(ingredient.text.strip())
# Out:
# 1 (3 pound) whole chicken
# 1 pinch salt
# ¼ cup butter, melted
# 1 tablespoon salt
# 1 tablespoon ground paprika
# ¼ tablespoon ground black pepper

# %% [markdown]
# # Parte 2: Obtener los datos deseados
# * Buscar dentro del contenido HTML y extraer la información.

# %%
# Extracting the description
description = soup.find("meta", {"name": "description"})["content"]

# Extracting the ingredients
ingredients_section = soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")
ingredients = [ingredient.get_text().strip() for ingredient in ingredients_section]

# Extracting the instructions
instructions_section = soup.find_all("p", class_="comp mntl-sc-block mntl-sc-block-html")
instructions = [instruction.get_text().strip() for instruction in instructions_section]

# Extracting the nutrition information
nutrition_section = soup.find_all("span", class_="mm-recipes-nutrition-facts-label__nutrient-name mm-recipes-nutrition-facts-label__nutrient-name--has-postfix")
nutrition_facts = [fact.parent.get_text().strip().replace('\n', ' ') for fact in nutrition_section]

# Print the extracted information
print("Recipe Title:", title)
print("Description:", description)
print("Ingredients:")
for ingredient in ingredients:
    print("-", ingredient)
print("Instructions:")
for i, instruction in enumerate(instructions, 1):
    print(f"{i}. {instruction}")
print("Nutrition Facts:")
for fact in nutrition_facts:
    print("-", fact)
# Out:
# Recipe Title: Rotisserie Chicken
# Description: Rotisserie chicken that's easy to cook on a gas grill and turns out moist and juicy with crispy skin. This is a simple recipe that our family loves.
# Ingredients:
# - 1 (3 pound) whole chicken
# - 1 pinch salt
# - ¼ cup butter, melted
# - 1 tablespoon salt
# - 1 tablespoon ground paprika
# - ¼ tablespoon ground black pepper
# Instructions:
# 22. Close the lid and cook over medium heat, basting occasionally, until chicken is cooked through and the internal temperature reaches 180 degrees F (83 degrees C), 1 to 1 1/2 hours.
# 23. Remove chicken from the rotisserie and let rest for 10 to 15 minutes before carving.
# Nutrition Facts:
# - Total Fat 25g
# - Saturated Fat 10g
# - Cholesterol 117mg
# - Sodium 1311mg
# - Total Carbohydrate 1g
# - Dietary Fiber 1g
# - Total Sugars 0g
# - Protein 31g
# - Vitamin C 1mg
# - Calcium 22mg
# - Iron 2mg
# - Potassium 302mg

# %%
def get_details(soup):
    # Extracting the recipe title
    title = soup.find("meta", {"property": "og:title"})["content"].strip()

    # Extracting the rating
    rating = soup.find("div", class_="mm-recipes-review-bar__rating")
    if not rating:
        rating = "No rating found"
    else:
        rating = rating.get_text().strip()

    # Extracting the time to prepare
    total_time_item = soup.find("div", class_="mm-recipes-details__label", string="Total Time:")
    if total_time_item:
        total_time = total_time_item.find_next_sibling("div", class_="mm-recipes-details__value").get_text().strip()
    else:
        total_time = "No total time found"

    # Extracting the servings
    servings_item = soup.find("div", class_="mm-recipes-details__label", string="Servings:")
    if servings_item:
        servings = servings_item.find_next_sibling("div", class_="mm-recipes-details__value").get_text().strip()
    else:
        servings = "No servings found"

    # Extracting the description
    description = soup.find("meta", {"property": "og:description"})["content"]
    if not description:
        description = "No description found"
    else:
        description = description.strip()
        
    # Extracting the ingredients
    ingredients_section = soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")
    ingredients = [ingredient.get_text().strip() for ingredient in ingredients_section]

    # Extracting the instructions
    instructions_section = soup.find_all("p", class_="comp mntl-sc-block mntl-sc-block-html")
    instructions = [instruction.get_text().strip() for instruction in instructions_section]

    # Extracting the nutrition information
    nutrition_section = soup.find_all("span", class_="mm-recipes-nutrition-facts-label__nutrient-name mm-recipes-nutrition-facts-label__nutrient-name--has-postfix")
    nutrition_facts = [fact.parent.get_text().strip().replace('\n', ' ') for fact in nutrition_section]

    # Extracting image
    image = soup.find("meta", {"property": "og:image"})
    if image:
        image_url = image["content"].strip()
    else:
        image_url = "No image found"
    
    # Extracting the full text of the recipe
    full_text = f"{title}. {rating}. {total_time}. {servings}. {description}. Ingredients: {', '.join(ingredients)}. Instructions: {' '.join(instructions)}. Nutrition Facts: {' '.join(nutrition_facts)}. Image URL: {image_url}"

    # Create a dictionary to hold all the details
    recipe_details = {
        "title": title,
        "rating": rating,
        "total_time": total_time,
        "servings": servings,
        "description": description,
        "ingredients": ingredients,
        "instructions": instructions,
        "nutrition_facts": nutrition_facts,
        "image_url": image_url,
        "full_text": full_text
    }
    
    return recipe_details

# %%
# Call the function to get details
get_details(soup)
# Out:
# {'title': 'Rotisserie Chicken',
#  'rating': '4.7',
#  'total_time': '1 hr 30 mins',
#  'servings': '6',
#  'description': "Rotisserie chicken that's easy to cook on a gas grill and turns out moist and juicy with crispy skin. This is a simple recipe that our family loves.",
#  'ingredients': ['1 (3 pound) whole chicken',
#   '1 pinch salt',
#   '¼ cup butter, melted',
#   '1 tablespoon salt',
#   '1 tablespoon ground paprika',
#   '¼ tablespoon ground black pepper'],
#  'instructions': ["Intimidated by the idea of making a rotisserie chicken at home? We're here to help. Get your grill and rotisserie attachment ready — you'll want to try this recipe ASAP.",
#   "Here's what you'll need to make rotisserie chicken at home:",
#   "· Whole Chicken: This recipe is meant for a whole 3-pound chicken. If your chicken is larger or smaller, you'll have to adjust the cooking time.· Butter: Butter keeps the chicken moist and juicy, while giving the seasonings something to stick to.· Seasonings: The rotisserie chicken is simply seasoned with salt, pepper, and paprika.",
#   "You'll find the full, step-by-step recipe below — but here's a brief overview of what you can expect when you make this rotisserie chicken:",
#   'Season the chicken cavity with salt and place it on a rotisserie (tie the wings and legs if you have twine or string available). Set the grill on high and cook for 10 minutes. Turn the grill down to medium and baste with a mixture of the butter and the seasonings. Close the lid and continue cooking, basting occasionally, until the chicken is cooked through. The internal temperature should reach at least 180 degrees F.',
#   'A cooked rotisserie chicken should stay good for about four days in a shallow, airtight container in the refrigerator.',
#   'Allow the chicken to cool for about 15 minutes before carving. To carve:',
#   '1. Place the chicken, breast-side up, on a cutting board.2. Pull one of the legs away from the body and slice through the meat until the hip bone is exposed. Then, pull the leg harder until the leg is detached.3. Use your knife to separate the drumstick and thigh.4. Pull the wing tip away from the breast until you can easily cut through the joint.5. Slice one of the breasts away from the breastbone. Repeat with the other breast.',
#   "If you go through the trouble of making a rotisserie chicken at home, you'll likely want to enjoy it on its own with a side salad or roasted vegetables.",
#   "What about the leftovers? Don't let even a bite of that chicken go to waste. Explore some of these mouthwatering collections for delicious inspiration:",
#   '· 23 Easy Weeknight Dinner Recipes That Use Rotisserie Chicken· 15 Easy 30-Minute Dinners That Start With Rotisserie Chicken· 15 No-Cook Meals You Can Make from Rotisserie Chicken',
#   'Reheat rotisserie chicken in the microwave, in the oven, or even in the air fryer.',
#   '· Microwave: Place the chicken on a plate, cover with a damp paper towel, and microwave until the chicken is heated through.· Oven: Place the chicken in a baking dish, pour in chicken broth (about ¼-inch deep), cover with aluminum foil, and bake at 400 degrees F for 15 to 20 minutes or until heated through.· Air Fryer: Place the chicken in the basket of the air fryer and cook at 350 degrees F for three to four minutes, or until crispy and heated through.',
#   '"This is only our second time using our grill\'s rotisserie attachment for the grill," says CHRISTINESAVILLE. "This recipe knocked the much more complex one out of the park! Delicious and easy to make! I wish I had a picture. It was perfect."',
#   '"This is the best rotisserie chicken I\'ve made, and I\'ll add, also beats baked," raves Melissa M. "Very juicy, done right, and great flavor. I put liquid smoke, pineapple juice and water in a pan underneath to add more moisture, and basted with butter and basil pesto every 30-45 min."',
#   '"We just got a new grill along with a rotisserie," says Dishy. "Couldn\'t wait to try it out and this recipe was perfect. I even did two chickens (Doubled the recipe) at one time and they both turned out great. Very moist and flavorful!"',
#   'Editorial contributions by Corey Williams',
#   'Gather all ingredients. Preheat an outdoor grill for high heat and lightly oil the grate.',
#   'Season chicken cavity with a pinch of salt. Tie legs together with kitchen string; then tie wings to the bird. Secure chicken on a rotisserie attachment.',
#   'Place rotisserie over the preheated grill and cook for 10 minutes.',
#   'Meanwhile, quickly mix together butter, 1 tablespoon of salt, paprika, and pepper. Turn the grill down to medium and baste chicken with butter mixture.',
#   'Close the lid and cook over medium heat, basting occasionally, until chicken is cooked through and the internal temperature reaches 180 degrees F (83 degrees C), 1 to 1 1/2 hours.',
#   'Remove chicken from the rotisserie and let rest for 10 to 15 minutes before carving.'],
#  'nutrition_facts': ['Total Fat 25g',
#   'Saturated Fat 10g',
#   'Cholesterol 117mg',
#   'Sodium 1311mg',
#   'Total Carbohydrate 1g',
#   'Dietary Fiber 1g',
#   'Total Sugars 0g',
#   'Protein 31g',
#   'Vitamin C 1mg',
#   'Calcium 22mg',
#   'Iron 2mg',
#   'Potassium 302mg'],
#  'image_url': 'https://www.allrecipes.com/thmb/iaKNJg3MdxbxONHCvfl6xwW0ZuA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/AR-93168-rotisserie-chicken-hero-2x1-560f1b49de8f4097b94e66a7232f7fd7.jpg',
#  'full_text': 'Rotisserie Chicken. 4.7. 1 hr 30 mins. 6. Rotisserie chicken that\'s easy to cook on a gas grill and turns out moist and juicy with crispy skin. This is a simple recipe that our family loves.. Ingredients: 1 (3 pound) whole chicken, 1 pinch salt, ¼ cup butter, melted, 1 tablespoon salt, 1 tablespoon ground paprika, ¼ tablespoon ground black pepper. Instructions: Intimidated by the idea of making a rotisserie chicken at home? We\'re here to help. Get your grill and rotisserie attachment ready — you\'ll want to try this recipe ASAP. Here\'s what you\'ll need to make rotisserie chicken at home: · Whole Chicken: This recipe is meant for a whole 3-pound chicken. If your chicken is larger or smaller, you\'ll have to adjust the cooking time.· Butter: Butter keeps the chicken moist and juicy, while giving the seasonings something to stick to.· Seasonings: The rotisserie chicken is simply seasoned with salt, pepper, and paprika. You\'ll find the full, step-by-step recipe below — but here\'s a brief overview of what you can expect when you make this rotisserie chicken: Season the chicken cavity with salt and place it on a rotisserie (tie the wings and legs if you have twine or string available). Set the grill on high and cook for 10 minutes. Turn the grill down to medium and baste with a mixture of the butter and the seasonings. Close the lid and continue cooking, basting occasionally, until the chicken is cooked through. The internal temperature should reach at least 180 degrees F. A cooked rotisserie chicken should stay good for about four days in a shallow, airtight container in the refrigerator. Allow the chicken to cool for about 15 minutes before carving. To carve: 1. Place the chicken, breast-side up, on a cutting board.2. Pull one of the legs away from the body and slice through the meat until the hip bone is exposed. Then, pull the leg harder until the leg is detached.3. Use your knife to separate the drumstick and thigh.4. Pull the wing tip away from the breast until you can easily cut through the joint.5. Slice one of the breasts away from the breastbone. Repeat with the other breast. If you go through the trouble of making a rotisserie chicken at home, you\'ll likely want to enjoy it on its own with a side salad or roasted vegetables. What about the leftovers? Don\'t let even a bite of that chicken go to waste. Explore some of these mouthwatering collections for delicious inspiration: · 23 Easy Weeknight Dinner Recipes That Use Rotisserie Chicken· 15 Easy 30-Minute Dinners That Start With Rotisserie Chicken· 15 No-Cook Meals You Can Make from Rotisserie Chicken Reheat rotisserie chicken in the microwave, in the oven, or even in the air fryer. · Microwave: Place the chicken on a plate, cover with a damp paper towel, and microwave until the chicken is heated through.· Oven: Place the chicken in a baking dish, pour in chicken broth (about ¼-inch deep), cover with aluminum foil, and bake at 400 degrees F for 15 to 20 minutes or until heated through.· Air Fryer: Place the chicken in the basket of the air fryer and cook at 350 degrees F for three to four minutes, or until crispy and heated through. "This is only our second time using our grill\'s rotisserie attachment for the grill," says CHRISTINESAVILLE. "This recipe knocked the much more complex one out of the park! Delicious and easy to make! I wish I had a picture. It was perfect." "This is the best rotisserie chicken I\'ve made, and I\'ll add, also beats baked," raves Melissa M. "Very juicy, done right, and great flavor. I put liquid smoke, pineapple juice and water in a pan underneath to add more moisture, and basted with butter and basil pesto every 30-45 min." "We just got a new grill along with a rotisserie," says Dishy. "Couldn\'t wait to try it out and this recipe was perfect. I even did two chickens (Doubled the recipe) at one time and they both turned out great. Very moist and flavorful!" Editorial contributions by Corey Williams Gather all ingredients ...

# %% [markdown]
# ## Parte 3: Obtener enlaces relacionados
# * Encontrar links a otras recetas para completar el corpus

# %%
import re
def get_recipe_urls(links):
    recipe_urls = []
    for link in links:
        href = link['href']
        # Filtro específico para el patrón de AllRecipes
        if re.search(r'/recipe/\d+/[\w-]+/?$', href):
            recipe_urls.append(href)
    return recipe_urls

# %%
# Find all the links to other recipes
recipe_links = soup.find_all("a", href=True)

# Filter and print only the links that are likely to be recipes
recipe_urls = get_recipe_urls(recipe_links)

# Print the recipe URLs
print("Linked Recipes:")
for url in recipe_urls:
    print(url)
# Out:
# Linked Recipes:
# https://www.allrecipes.com/recipe/238575/cilantro-lime-grilled-chicken/
# https://www.allrecipes.com/recipe/275062/buttermilk-barbecue-chicken/
# https://www.allrecipes.com/recipe/274724/grilled-spatchcocked-chicken/
# https://www.allrecipes.com/recipe/14531/beer-butt-chicken/
# https://www.allrecipes.com/recipe/221093/good-frickin-paprika-chicken/
# https://www.allrecipes.com/recipe/264278/miso-honey-chicken/
# https://www.allrecipes.com/recipe/258659/rosemary-buttermilk-chicken/
# https://www.allrecipes.com/recipe/222936/smoked-beer-butt-chicken/
# https://www.allrecipes.com/recipe/228070/the-best-beer-can-chicken-ever/
# https://www.allrecipes.com/recipe/214619/bbq-beer-can-chicken/
# https://www.allrecipes.com/recipe/19944/drunk-chicken/
# https://www.allrecipes.com/recipe/275044/grilled-chicken-under-a-brick/
# https://www.allrecipes.com/recipe/281255/smoked-whole-chicken/
# https://www.allrecipes.com/recipe/34957/easy-barbeque-chicken/
# https://www.allrecipes.com/recipe/8998/darn-good-chicken/
# https://www.allrecipes.com/recipe/214618/beer-can-chicken/

# %%
import requests

# %%
def extract_recipe_links(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Accept-Language": "en-US,en;q=0.9",
        "Connection": "keep-alive",
        "Upgrade-Insecure-Requests": "1"
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for HTTP errors
        soup = BeautifulSoup(response.content, "html.parser")
        recipe_links = soup.find_all("a", href=True)
        return get_recipe_urls(recipe_links)
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch {url}: {e}")

# %%
category_urls = [
    "https://www.allrecipes.com/recipes/17562/dinner/",
    "https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/",
    "https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/",
    "https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/",
    "https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/",
    "https://www.allrecipes.com/recipes/17889/everyday-cooking/family-friendly/family-dinners/",
    "https://www.allrecipes.com/recipes/94/soups-stews-and-chili/",
    "https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/",
    "https://www.allrecipes.com/recipes/80/main-dish/",
    "https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/",
    "https://www.allrecipes.com/recipes-a-z-6735880/",
    "https://www.allrecipes.com/recipes/78/breakfast-and-brunch/",
    "https://www.allrecipes.com/recipes/17561/lunch/",
    "https://www.allrecipes.com/recipes/84/healthy-recipes/",
    "https://www.allrecipes.com/recipes/76/appetizers-and-snacks/",
    "https://www.allrecipes.com/recipes/96/salad/",
    "https://www.allrecipes.com/recipes/81/side-dish/",
    "https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/",
    "https://www.allrecipes.com/recipes/156/bread/",
    "https://www.allrecipes.com/recipes/77/drinks/",
    "https://www.allrecipes.com/recipes/79/desserts/",
    "https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/",
    "https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/",
    "https://www.allrecipes.com/recipes/205/meat-and-poultry/pork/",
    "https://www.allrecipes.com/recipes/93/seafood/",
    "https://www.allrecipes.com/recipes/95/pasta-and-noodles/",
    "https://www.allrecipes.com/recipes/1058/fruits-and-vegetables/fruits/",
    "https://www.allrecipes.com/recipes/1059/fruits-and-vegetables/vegetables/",
    "https://www.allrecipes.com/recipes/728/world-cuisine/latin-american/mexican/",
    "https://www.allrecipes.com/recipes/723/world-cuisine/european/italian/",
    "https://www.allrecipes.com/recipes/695/world-cuisine/asian/chinese/",
    "https://www.allrecipes.com/recipes/233/world-cuisine/asian/indian/",
    "https://www.allrecipes.com/recipes/722/world-cuisine/european/german/",
    "https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/",
    "https://www.allrecipes.com/recipes/696/world-cuisine/asian/filipino/",
    "https://www.allrecipes.com/recipes/699/world-cuisine/asian/japanese/"
]

# %%
# Processing category URLs to extract recipe links
all_recipe_urls = []
for url in category_urls:
    all_recipe_urls.extend(extract_recipe_links(url))

all_recipe_urls = list(set(all_recipe_urls))  # Remove duplicates
all_recipe_urls
# Out:
# ['https://www.allrecipes.com/recipe/140422/onigiri-japanese-rice-balls/',
#  'https://www.allrecipes.com/recipe/23893/kraut-bierocks/',
#  'https://www.allrecipes.com/recipe/14759/pork-dumplings/',
#  'https://www.allrecipes.com/recipe/139425/filipino-avocado-milkshake/',
#  'https://www.allrecipes.com/recipe/100008/homemade-pickled-ginger-gari/',
#  'https://www.allrecipes.com/recipe/8472782/frito-chicken-casserole/',
#  'https://www.allrecipes.com/recipe/241502/esers-balsamic-salad-dressing/',
#  'https://www.allrecipes.com/recipe/239047/one-pan-orecchiette-pasta/',
#  'https://www.allrecipes.com/recipe/166667/halloumi-cheese-fingers/',
#  'https://www.allrecipes.com/recipe/142881/german-schwenkbraten/',
#  'https://www.allrecipes.com/recipe/260193/instant-pot-salsa-chicken/',
#  'https://www.allrecipes.com/recipe/231287/sausage-potato-and-kale-soup/',
#  'https://www.allrecipes.com/recipe/274884/falafel-with-canned-chickpeas/',
#  'https://www.allrecipes.com/recipe/255401/chicken-afritada-filipino-stew/',
#  'https://www.allrecipes.com/recipe/235158/worlds-best-honey-garlic-pork-chops/',
#  'https://www.allrecipes.com/recipe/146579/general-tao-chicken/',
#  'https://www.allrecipes.com/recipe/35151/traditional-filipino-lumpia/',
#  'https://www.allrecipes.com/recipe/255462/lasagna-flatbread/',
#  'https://www.allrecipes.com/recipe/15156/easy-chicken-curry/',
#  'https://www.allrecipes.com/recipe/149799/easy-cold-pasta-salad/',
#  'https://www.allrecipes.com/recipe/80969/simple-turkey-chili/',
#  'https://www.allrecipes.com/recipe/260850/japanese-pan-noodles/',
#  'https://www.allrecipes.com/recipe/239428/crispy-panko-chicken-breasts/',
#  'https://www.allrecipes.com/recipe/9025/bourbon-chicken/',
#  'https://www.allrecipes.com/recipe/258755/simple-custard/',
#  'https://www.allrecipes.com/recipe/212487/lamb-gosht-biryani/',
#  'https://www.allrecipes.com/recipe/190094/miso-and-soy-chilean-sea-bass/',
#  'https://www.allrecipes.com/recipe/18842/my-own-famous-stuffed-grape-leaves/',
#  'https://www.allrecipes.com/recipe/34668/chinese-fried-noodles/',
#  'https://www.allrecipes.com/recipe/36621/philly-steak-sandwich/',
#  'https://www.allrecipes.com/recipe/16311/simple-beef-stroganoff/',
#  'https://www.allrecipes.com/recipe/72349/indian-style-basmati-rice/',
#  'https://www.allrecipes.com/recipe/228957/authentic-saag-paneer/',
#  'https://www.allrecipes.com/recipe/13045/broccoli-cheese-soup/',
#  'https://www.allrecipes.com/recipe/16824/easy-breaded-shrimp/',
#  'https://www.allrecipes.com/recipe/245065/rainbow-juice/',
#  'https://www.allrecipes.com/recipe/228293/curry-stand-chicken-tikka-masala-sauce/',
#  'https://www.allrecipes.com/recipe/73715/paneer/',
#  'https://www.allrecipes.com/recipe/263693/japanese-agedashi-tofu/',
#  'https://www.allrecipes.com/recipe/18454/cabbage-and-kielbasa/',
#  'https://www.allrecipes.com/recipe/74915/amish-macaroni-salad/',
#  'https://www.allrecipes.com/recipe/127500/japanese-style-deep-fried-shrimp/',
#  'https://www.allrecipes.com/recipe/84242/schnitzel/',
#  'https://www.allrecipes.com/recipe/40351/lumpia-shanghai-version/',
#  'https://www.allrecipes.com/recipe/176957/baked-kale-chips/',
#  'https://www.allrecipes.com/recipe/231939/honey-glazed-chicken/',
#  'https://www.allrecipes.com/recipe/240974/a-healthy-egg-salad/',
#  'https://www.allrecipes.com/recipe/228406/beer-glazed-brats-and-sauerkraut/',
#  'https://www.allrecipes.com/recipe/24676/german-currywurst/',
#  'https://www.allrecipes.com/recipe/241873/avgolemono-soup/',
#  'https://www.allrecipes.com/recipe/90253/pumpkin-mochi/',
#  'https://www.allrecipes.com/recipe/8509102/chicken-al-pastor/',
#  'https://www.allrecipes.com/recipe/219325/german-rice/',
#  'https://www.allrecipes.com/recipe/162361/gyoza-sauce/',
#  'https://www.allrecipes.com/recipe/236814/baked-fresh-rainbow-trout/',
#  'https://www.allrecipes.com/recipe/237899/filippino-lechon-kawali/',
#  'https://www.allrecipes.com/recipe/212929/chicken-tinola/',
#  'https://www.allrecipes.com/recipe/20095/szechuan-beef/',
#  'https://www.allrecipes.com/recipe/14746/mushroom-pork-chops/',
#  'https://www.allrecipes.com/recipe/221132/magnificent-macaroni-salad/',
#  'https://www.allrecipes.com/recipe/14385/pasta-salad/',
#  'https://www.allrecipes.com/recipe/11751/simple-mac-and-cheese/',
#  'https://www.allrecipes.com/recipe/213010/siopao-filipino-steamed-buns/',
#  'https://www.allrecipes.com/recipe/283464/easy-plum-cake/',
#  'https://www.allrecipes.com/recipe/85337/microwave-baked-potato/',
#  'https://www.allrecipes.com/recipe/63959/magic-cookie-bars-from-eagle-brand/',
#  'https://www.allrecipes.com/recipe/15271/german-anise-christmas-cookies-springerle/',
#  'https://www.allrecipes.com/recipe/70019/egg-butter/',
#  'https://www.allrecipes.com/recipe/259371/taramosalata/',
#  'https://www.allrecipes.com/recipe/22538/baked-salmon-fillets-dijon/',
#  'https://www.allrecipes.com/recipe/262533/chicken-apple-and-brussels-sprout-sheet-pan-dinner/',
#  'https://www.allrecipes.com/recipe/51518/ube-macapuno-cake/',
#  'https://www.allrecipes.com/recipe/214086/tracis-adobo-seasoning/',
#  'https://www.allrecipes.com/recipe/23157/turkey-in-a-bag/',
#  'https://www.allrecipes.com/recipe/278065/quick-pickled-red-cabbage-atchara/',
#  'https://www.allrecipes.com/recipe/47015/quick-and-easy-pancit/',
#  'https://www.allrecipes.com/recipe/282251/croque-madame-sandwich/',
#  'https://www.allrecipes.com/recipe/232375/natashas-chicken-burgers/',
#  'https://www.allrecipes.com/recipe/16354/easy-meatloaf/',
#  'https://www.allrecipes.com/recipe/233531/quick-whole-wheat-chapati/',
#  'https://www.allrecipes.com/recipe/76161/real-homemade-bologna/',
#  'https://www.allrecipes.com/recipe/174543/slow-cooker-butter-chicken/',
#  'https://www.allrecipes.com/recipe/262162/sheet-pan-salmon-and-bell-pepper-dinner/',
#  'https://www.allrecipes.com/recipe/269330/sheet-pan-roasted-mediterranean-vegetables/',
#  'https://www.allrecipes.com/recipe/273598/moo-shu-chicken/',
#  'https://www.allrecipes.com/recipe/33252/indian-style-sheekh-kabab/',
#  'https://www.allrecipes.com/recipe/221923/japanese-tamago-egg/',
#  'https://www.allrecipes.com/recipe/8495/chicken-cordon-bleu-i/',
#  'https://www.allrecipes.com/recipe/241630/creamy-beef-tips-with-egg-noodles/',
#  'https://www.allrecipes.com/recipe/222214/creamy-macaroni-salad/',
#  'https://www.allrecipes.com/recipe/8453629/caprese-pasta-with-thai-basil/',
#  'https://www.allrecipes.com/recipe/24228/sushi-roll/',
#  'https://www.allrecipes.com/recipe/74203/kheer-rice-pudding/',
#  'https://www.allrecipes.com/recipe/34613/roquefort-pear-salad/',
#  'https://www.allrecipes.com/recipe/269230/sheet-pan-smoked-sausage-apple-and-root-veggie-dinner/',
#  'https://www.allrecipes.com/recipe/214091/flan-mexicano-mexican-flan/',
#  'https://www.allrecipes.com/recipe/214464/chinese-chicken-wings/',
#  'https://www.allrecipes.com/recipe/222015/grillhaxe-grilled-eisbein-pork-shanks/',
#  'https://www.allrecipes.com/recipe/212932/filipino-chicken-salad/',
#  'https://www.allrecipes.com/recipe/46982/pesto-pasta-with-chicken/',
#  'https://www.allrecipes.com/recipe/57716/shrimp-with-lobster-sauce/',
#  'https://www.allrecipes.com/recipe/82768/lauras-quick-slow-cooker-turkey-chili/',
#  'https://www.allrecipes.com/recipe/282238/gajar-ka-halwa-carrot-halwa/',
#  'https://www.allrecipes.com/recipe/76659/heavenly-halibut/',
#  'https://www.allrecipes.com/recipe/8919/grilled-asian-chicken/',
#  'https://www.allrecipes.com/recipe/142967/easy-garam-masala/',
#  'https://www.allrecipes.com/recipe/150123/traditional-springerle/',
#  'https://www.allrecipes.com/recipe/174210/super-easy-stir-fried-cabbage/',
#  'https://www.allrecipes.com/recipe/72159/easy-baked-oatmeal/',
#  'https://www.allrecipes.com/recipe/280769/fresh-summer-corn-salad/',
#  'https://www.allrecipes.com/recipe/34870/chicken-murphy/',
#  'https://www.allrecipes.com/recipe/212498/easy-chicken-and-broccoli-alfredo/',
#  'https://www.allrecipes.com/recipe/13199/wonton-soup/',
#  'https://www.allrecipes.com/recipe/280690/pecan-chicken-salad/',
#  'https://www.allrecipes.com/recipe/16700/salsa-chicken/',
#  'https://www.allrecipes.com/recipe/8506346/chef-johns-chicken-fricassee/',
#  'https://www.allrecipes.com/recipe/51301/sarahs-applesauce/',
#  'https://www.allrecipes.com/recipe/244200/chef-johns-beef-rouladen/',
#  'https://www.allrecipes.com/recipe/277279/bistek-filipino-beef-steak/',
#  'https://www.allrecipes.com/recipe/78117/wienerschnitzel/',
#  'https://www.allrecipes.com/recipe/263567/the-denver-omelet/',
#  'https://www.allrecipes.com/recipe/45957/chicken-makhani-indian-butter-chicken/',
#  'https://www.allrecipes.com/recipe/20287/easy-baklava/',
#  'https://www.allrecipes.com/recipe/9482/scotch-eggs/',
#  'https://www.allrecipes.com/recipe/232203/paneer-butter-masala/',
#  'https://www.allrecipes.com/recipe/16729/old-fashioned-potato-salad/',
#  'https://www.allrecipes.com/recipe/229032/parchment-baked-salmon/',
#  'https://www.allrecipes.com/recipe/231061/easy-baked-ham-steaks/',
#  'https://www.allrecipes.com/recipe/212721/indian-chicken-curry-murgh-kari/',
#  'https://www.allrecipes.com/recipe/241890/grilled-chicken-marinade/',
#  'https://www.allrecipes.com/recipe/212956/empanada-dough/',
#  'https://www.allrecipes.com/recipe/17161/chinese-chicken-fried-rice-i/',
#  'https://www.allrecipes.com/recipe/172704/chinese-pepper-steak/',
#  'https://www.allrecipes.com/recipe/228767/peach-bellini/',
#  'https://www.allrecipes.com/recipe/233985/chocolate-protein-balls/',
#  'https://www.allrecipes.com/recipe/272858/air-fryer-chicken-thighs/',
#  'https://www.allrecipes.com/recipe/25407/reuben-casserole/',
#  'https://www.allrecipes.com/recipe/16110/greek-garbanzo-bean-salad/',
#  'https://www.allrecipes.com/recipe/262696/cheese-omelette/',
#  'https://www.allrecipes.com/recipe/71387/best-salmon-bake/',
#  'https://www.allrecipes.com/recipe/255936/chicken-sausage-peppers-and-potatoes/',
#  'https://www.allrecipes.com/recipe/31848/jambalaya/',
#  'https://www.allrecipes.com/recipe/236294/haldi-ka-doodh-hot-turmeric-milk/',
#  'https://www.allrecipes.com/recipe/70163/easy-baked-tilapia/',
#  'https://www.allrecipes.com/recipe/31144/sweet-and-sour-pork-iii/',
#  'https://www.allrecipes.com/recipe/212636/japanese-beef-stir-fry/',
#  'https://www.allrecipes.com/recipe/236432/brown-sugar-ham-steak/',
#  'https://www.allrecipes.com/recipe/257108/pepperoni-pizza-pasta-salad/',
#  'https://www.allrecipes.com/recipe/19644/moussaka/',
#  'https://www.allrecipes.com/recipe/90500/beet-salad-with-goat-cheese/',
#  'https://www.allrecipes.com/recipe/285369/classic-chicken-salad/',
#  'https://www.allrecipes.com/recipe/230620/mayo-chicken/',
#  'https://www.allrecipes.com/recipe/29704/easy-chinese-corn-soup/',
#  'https://www.allrecipes.com/recipe/130979/day-after-thanksgiving-turkey-carcass-soup/',
#  'https://www.allrecipes.com/recipe/16310/corned-beef-and-cabbage-i/',
#  'https://www.allrecipes.com/recipe/13087/mulligatawny-soup-i/',
#  'https://www.allrecipes.com/recipe/24871/beef-samosas/',
#  'https://www.allrecipes.com/recipe/6714/banana-oat-muffins/',
#  'https://www.allrecipes.com/recipe/212954/filipino-fish-escabeche/',
#  'https://www.allrecipes.com/recipe/263750/flaming-greek-cheese-saganaki/',
#  'https://www.allrecipes.com/recipe/241849/greek-easter-eggs/',
#  'https://www.allrecipes.com/recipe/83196/hamburger-jazz/',
#  'https://www.allrecipes.com/recipe/228239/caldereta-filipino-beef-stew/',
#  'https://www.allrecipes.com/recipe/238691/simple-macaroni-and-cheese/',
#  'https://www.allrecipes.com/recipe/19389/greek-orzo-salad/',
#  'https://www.allrecipes.com/recipe/255402/sinigang-na-isda-sa-miso-fish-stew-with-miso/',
#  'https://www.allrecipes.com/recipe/236780/the-best-lemon-vinaigrette/',
#  'https://www.allrecipes.com/recipe/237321/cherry-tomato-sauce-with-penne/',
#  'https://www.allrecipes.com/recipe/263602/sheet-pan-vegan-roasted-brussels-sprouts-and-butternut-squash/',
#  'https://www.allrecipes.com/recipe/10549/best-brownies/',
#  'https://www.allrecipes.com/recipe/61024/asian-orange-chicken/',
#  'https://www.allrecipes.com/recipe/53514/pepperoni-casserole/',
#  'https://www.allrecipes.com/recipe/26611/sheet-pan-ground-beef-potato-and-carrot-dinner/',
#  'https://www.allrecipes.com/recipe/24445/chewy-chocolate-chip-oatmeal-cookies/',
#  'https://www.allrecipes.com/recipe/241074/easy-garlic-kale/',
#  'https://www.allrecipes.com/recipe/234949/authentic-russian-salad-olivye/',
#  'https://www.allrecipes.com/recipe/34450/italian-seasoning-i/',
#  'https://www.allrecipes.com/recipe/228630/slow-cooker-pork-and-sauerkraut/',
#  'https://www.allrecipes.com/recipe/8541/carols-arroz-con-pollo/',
#  'https://www.allrecipes.com/recipe/13384/split-pea-soup/',
#  'https://www.allrecipes.com/recipe/150738/wedge-salad-with-elegant-blue-cheese-dressing/',
#  'https://www.allrecipes.com/recipe/265087/uova-in-purgatorio-eggs-in-purgatory/',
#  'https://www.allrecipes.com/recipe/51326/chinese-tea-leaf-eggs/',
#  'https://www.allrecipes.com/recipe/8887/chicken-marsala/',
#  'https://www.allrecipes.com/recipe/230857/easy-tuna-patties/',
#  'https://www.allrecipes.com/recipe/222750/quick-italian-pasta-salad/',
#  'https://www.allrecipes.com/recipe/204821/ginataang-manok-chicken-cooked-in-coconut-milk/',
#  'https://www.allrecipes.com/recipe/25194/german-rouladen/',
#  'https://www.allrecipes.com/recipe/231367/easy-crispy-baked-chicken/',
#  'https://www.allrecipes.com/recipe/12775/spicy-grilled-shrimp/',
#  'https://www.allrecipes.com/recipe/237284/creamy-avocado-chicken-salad/',
#  'https://www.allrecipes.com/recipe/76954/roasted-new-red-potatoes/',
#  'https://www.allrecipes.com/recipe/228953/california-roll/',
#  'https://www.allrecipes.com/recipe/228065/watermelon-pickles/',
#  'https://www.allrecipes.com/recipe/236760/hot-muffuletta-dip/',
#  'https://www.allrecipes.com/recipe/140930/southern-fried-catfish/',
#  'https://www.allrecipes.com/recipe/69451/summer-pepper-salad/',
#  'https://www.allrecipes.com/recipe/245210/prosciutto-wrapped-pork-tenderloin-with-crispy-sage/',
#  'https://www.allrecipes.com/recipe/221361/traditional-sauerbraten/',
#  'https://www.allrecipes.com/recipe/212924/filipino-baked-milkfish-baked-bangus/',
#  'https://www.allrecipes.com/recipe/258032/karaage-japanese-fried-chicken-with-honey-mayoster-sauce/',
#  'https://www.allrecipes.com/recipe/258067/spargel-in-schinken-white-asparagus-wrapped-in-ham/',
#  'https://www.allrecipes.com/recipe/86649/fast-english-muffin-pizzas/',
#  'https://www.allrecipes.com/recipe/21306/fish-in-foil/',
#  'https://www.allrecipes.com/recipe/14056/copper-penny/',
#  'https://www.allrecipes.com/recipe/13287/creamy-italian-white-bean-soup/',
#  'https://www.allrecipes.com/recipe/280310/two-ingredient-naan/',
#  'https://www.allrecipes.com/recipe/278364/baked-rigatoni-for-a-crowd/',
#  'https://www.allrecipes.com/recipe/233761/cucumber-soup-with-tomatoes/',
#  'https://www.allrecipes.com/recipe/19963/fajita-marinade-i/',
#  'https://www.allrecipes.com/recipe/264349/my-mango-lassi/',
#  'https://www.allrecipes.com/recipe/11679/homemade-mac-and-cheese/',
#  'https://www.allrecipes.com/recipe/214367/watermelon-agua-fresca/',
#  'https://www.allrecipes.com/recipe/140444/tomato-gorgonzola-soup/',
#  'https://www.allrecipes.com/recipe/242342/fiesta-slow-cooker-shredded-chicken-tacos/',
#  'https://www.allrecipes.com/recipe/201093/eel-sauce/',
#  'https://www.allrecipes.com/recipe/17219/best-tuna-casserole/',
#  'https://www.allrecipes.com/recipe/217939/old-fashioned-pea-salad/',
#  'https://www.allrecipes.com/recipe/13637/three-bean-salad/',
#  'https://www.allrecipes.com/recipe/107586/teriyaki-rib-eye-steaks/',
#  'https://www.allrecipes.com/recipe/283771/schupfnudeln-german-fried-potato-dumplings/',
#  'https://www.allrecipes.com/recipe/86323/yeast-dumplings/',
#  'https://www.allrecipes.com/recipe/137650/greek-lentil-soup-fakes/',
#  'https://www.allrecipes.com/recipe/220751/quick-chicken-piccata/',
#  'https://www.allrecipes.com/recipe/268843/sheet-pan-shrimp-and-sausage-bake/',
#  'https://www.allrecipes.com/recipe/149686/german-beef-rouladen/',
#  'https://www.allrecipes.com/recipe/220164/classic-cuban-style-picadillo/',
#  'https://www.allrecipes.com/recipe/268999/mediterranean-chicken-sheet-pan-dinner/',
#  'https://www.allrecipes.com/recipe/97621/foolproof-rib-roast/',
#  'https://www.allrecipes.com/recipe/9822/pfeffernusse/',
#  'https://www.allrecipes.com/recipe/269004/one-pot-spaghetti-with-meat-sauce/',
#  'https://www.allrecipes.com/recipe/44975/easy-pizza-sauce-iii/',
#  'https://www.allrecipes.com/recipe/8039/bee-sting-cake-bienenstich-ii/',
#  'https://www.allrecipes.com/recipe/215231/empanadas-beef-turnovers/',
#  'https://www.allrecipes.com/recipe/212935/buchi/',
#  'https://www.allrecipes.com/recipe/244520/belizean-chicken-stew/',
#  'https://www.allrecipes.com/recipe/282114/beef-birria-queso-tacos-with-consome/',
#  'https://www.allrecipes.com/recipe/14050/cucumber-sunomono/',
#  'https://www.allrecipes.com/recipe/235851/how-to-cook-trout/',
#  'https://www.allrecipes.com/recipe/215314/slow-cooker-baked-potatoes/',
#  'https://www.allrecipes.com/recipe/228115/2-minute-cheese-quesadillas/',
#  'https://www.allrecipes.com/recipe/17673/carrot-bread-i/',
#  'https://www.allrecipes.com/recipe/14756/filipino-ribs/',
#  'https://www.allrecipes.com/recipe/279434/spicy-tuna-rolls/',
#  'https://www.allrecipes.com/recipe/24332/ultimate-twice-baked-potatoes/',
#  'https://www.allrecipes.com/recipe/85935/jaeger-schnitzel/',
#  'https://www.allrecipes.com/recipe/179774/sugar-salad/',
#  'https://www.allrecipes.com/recipe/45515/restaurant-style-egg-drop-soup/',
#  'https://www.allrecipes.com/recipe/261583/german-homemade-marzipan/',
#  'https://www.allrecipes.com/recipe/15327/capirotada-mexican-bread-pudding/',
#  'https://www.allrecipes.com/recipe/262439/sinigang-na-bangus-filipino-milkfish-in-tamarind-broth/',
#  'https://www.allrecipes.com/recipe/141169/easy-indian-butter-chicken/',
#  'https://www.allrecipes.com/recipe/12477/steak-and-kidney-pie-ii/',
#  'https://www.allrecipes.com/recipe/20963/oven-roasted-potatoes/',
#  'https://www.allrecipes.com/recipe/235712/honey-lime-vinaigrette/',
#  'https://www.allrecipes.com/recipe/282584/chinese-black-bean-sauce/',
#  'https://www.allrecipes.com/recipe/212941/cassava-cake/',
#  'https://www.allrecipes.com/recipe/278767/greek-horiatiki-salad/',
#  'https://www.allrecipes.com/recipe/188444/mexican-bean-and-rice-salad/',
#  'https://www.allrecipes.com/recipe/201934/pan-seared-tilapia/',
#  'https://www.allrecipes.com/recipe/8499/basic-chicken-salad/',
#  'https://www.allrecipes.com/recipe/239867/chef-johns-chicken-tikka-masala/',
#  'https://www.allrecipes.com/recipe/25311/vegetarian-moussaka/',
#  'https://www.allrecipes.com/recipe/18465/gnocchi-i/',
#  'https://www.allrecipes.com/recipe/274001/bacon-on-the-grill/',
#  'https://www.allrecipes.com/recipe/240584/quark-homemade-cheese/',
#  'https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/',
#  'https://www.allrecipes.com/recipe/276320/grandmas-chicken-soup/',
#  'https://www.allrecipes.com/recipe/23074/bobs-stuffed-banana-peppers/',
#  'https://www.allrecipes.com/recipe/18871/easy-tuna-casserole/',
#  'https://www.allrecipes.com/recipe/16239/easy-slow-cooker-french-dip/',
#  'https://www.allrecipes.com/recipe/132358/easy-garlic-lemon-scallops/',
#  'https://www.allrecipes.com/recipe/229210/fiesta-tater-tot-casserole/',
#  'https://www.allrecipes.com/recipe/274966/sheet-pan-parmesan-chicken-and-veggies/',
#  'https://www.allrecipes.com/recipe/212994/pinakbet/',
#  'https://www.allrecipes.com/recipe/262423/leche-flan/',
#  'https://www.allrecipes.com/recipe/212449/gujarati-kadhi/',
#  'https://www.allrecipes.com/recipe/270708/lumpia-in-the-air-fryer/',
#  'https://www.allrecipes.com/recipe/38028/blackened-fish/',
#  'https://www.allrecipes.com/recipe/16151/pan-de-sal-i/',
#  'https://www.allrecipes.com/recipe/263557/filipino-chicken-sopas/',
#  'https://www.allrecipes.com/recipe/168941/sicilian-homemade-ricotta-cheese/',
#  'https://www.allrecipes.com/recipe/13218/absolutely-ultimate-potato-soup/',
#  'https://www.allrecipes.com/recipe/31522/greek-style-potatoes/',
#  'https://www.allrecipes.com/recipe/223597/old-fashioned-potato-cakes/',
#  'https://www.allrecipes.com/recipe/76455/pork-and-chicken-adobo/',
#  'https://www.allrecipes.com/recipe/245367/pan-roasted-chicken-breasts/',
#  'https://www.allrecipes.com/recipe/214947/perfect-summer-fruit-salad/']

# %%
# all_recipes
recipes_data = []
def fetch_recipe_content(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Accept-Language": "en-US,en;q=0.9",
        "Connection": "keep-alive",
        "Upgrade-Insecure-Requests": "1"
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for HTTP errors
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Call the function to get details from the fetched content
        recipe_details = get_details(soup)
        recipes_data.append(recipe_details)

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch {url}: {e}")

# Loop through the list of recipe URLs and fetch their contents
print("Recopilando recetas...")
for url in all_recipe_urls[:100]:
    fetch_recipe_content(url)
# Out:
# Recopilando recetas...

# %%
# Create a DataFrame from the recipes data
import pandas as pd
recipes_df = pd.DataFrame(recipes_data)
recipes_df.head()
# Out:
#                             title rating    total_time servings  \
# 0   Onigiri (Japanese Rice Balls)    4.4          1 hr        4
# 1                  Kraut Bierocks    4.6  1 hr 45 mins       10
# 2                  Pork Dumplings    4.7          1 hr       10
# 3      Filipino Avocado Milkshake    4.7        5 mins        2
# 4  Homemade Pickled Ginger (Gari)    4.7       45 mins       32
#
#                                          description  \
# 0  This onigiri recipe is fun to make for Japanes...
# 1  These meat-mixture filled rolls make a great m...
# 2  These amazingly easy steamed pork dumplings ha...
# 3  This avocado milkshake made with milk, sugar, ...
# 4  Pickled ginger, or gari, is served as a palate...
#
#                                          ingredients  \
# 0  [4 cups uncooked short-grain white rice, 5 ½ c...
# 1  [1 ½ (.25 ounce) packages active dry yeast, ½ ...
# 2  [100  (3.5 inch square) wonton wrappers, 1 ¾ p...
# 3  [1 medium avocado - peeled, pitted, and cubed,...
# 4  [8 ounces fresh young ginger root, peeled, 1 ½...
#
#                                         instructions  \
# 0  [Wash rice in a mesh strainer until water runs...
# 1  [To Make Sweet Dough: In a medium bowl combine...
# 2  [If you're looking for the best steamed pork d...
# 3  [Combine avocado, milk, ice cream, ice, sugar,...
# 4  [Gather all ingredients., Cut ginger into chun...
#
#                                      nutrition_facts  \
# 0  [Total Fat 3g, Saturated Fat 1g, Sodium 160mg,...
# 1  [Total Fat 34g, Saturated Fat 13g, Cholesterol...
# 2  [Total Fat 29g, Saturated Fat 9g, Cholesterol ...
# 3  [Total Fat 19g, Saturated Fat 5g, Cholesterol ...
# 4  [Total Fat 0g, Sodium 83mg, Total Carbohydrate...
#
#                                            image_url  \
# 0  https://www.allrecipes.com/thmb/Xed7WCnxYS6lPa...
# 1  https://www.allrecipes.com/thmb/Z2_ZSaelT_MOC4...
# 2  https://www.allrecipes.com/thmb/tCt2q6Sly6Spyu...
# 3  https://www.allrecipes.com/thmb/d-YvB22kgzjN3T...
# 4  https://www.allrecipes.com/thmb/AiFUs73Pna0irz...
#
#                                            full_text
# 0  Onigiri (Japanese Rice Balls). 4.4. 1 hr. 4. T...
# 1  Kraut Bierocks. 4.6. 1 hr 45 mins. 10. These m...
# 2  Pork Dumplings. 4.7. 1 hr. 10. These amazingly...
# 3  Filipino Avocado Milkshake. 4.7. 5 mins. 2. Th...
# 4  Homemade Pickled Ginger (Gari). 4.7. 45 mins. ...

# %%
## Segundo Método para buscar Recetas
# Buscar todos los enlaces <a href="..."> en el HTML

#recipe_links = soup.find_all("a", href=True)

# Filtrar solo los que empiezan con el patrón deseado
#recipe_urls = []
#for link in recipe_links:
#    href = link['href']
#    if href.startswith("https://www.allrecipes.com/recipe"):
#        recipe_urls.append(href)

# Eliminar duplicados (opcional pero recomendado)
#recipe_urls = list(set(recipe_urls))

# Mostrar los enlaces filtrados
#print("🔗 Enlaces a recetas:")
#for url in recipe_urls:
#    print(url)

# %% [markdown]
# # Parte 4: Hacer RAG con las recetas obtenidas
# * Una vez que se ha construido el corpus, implementar y desplegar RAG para realizar búsquedas en el corpus

# %%
# Create embeddings for the recipes data
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Generando embeddings...")
embeddings = model.encode(recipes_df['full_text'].tolist(), convert_to_numpy=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Generando embeddings...
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Create index FAISS
index = faiss.IndexFlatL2(embeddings.shape[1])  # L2 distance
index.add(embeddings)  # Add embeddings to the index
# Adding embeddings to DataFrame
recipes_df['embeddings'] = embeddings.tolist()  # Convert numpy array to list for Data

# %%
def seeker(query, k=5):
    """
    Function to search for recipes based on a query.
    Returns the top k recipes based on cosine similarity.
    """
    query_embedding = model.encode([query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding, k)
    
    context_recipes = []
    recipe_summaries = []
    for i in range(k):
        recipe = recipes_df.iloc[indices[0][i]]
        context_recipes.append({
            "title": recipe['title'],
            "rating": recipe['rating'],
            "total_time": recipe['total_time'],
            "servings": recipe['servings'],
            "description": recipe['description'],
            "ingredients": recipe['ingredients'],
            "instructions": recipe['instructions'],
            "nutrition_facts": recipe['nutrition_facts'],
            "image_url": recipe['image_url'],
            "distance": distances[0][i]
        })
        
        # Create a summary for the recipe
        summary = f"{recipe['title']} - {recipe['rating']} stars, {recipe['total_time']} to prepare, serves {recipe['servings']}. {recipe['description']}. Ingredients: {', '.join(recipe['ingredients'])}. Instructions: {' '.join(recipe['instructions'])}. Nutrition Facts: {' '.join(recipe['nutrition_facts'])}. Image URL: {recipe['image_url']}"
        recipe_summaries.append(summary)
    
    # Create prompt for ChatGPT
    prompt = f"""
    Basándote únicamente en las siguientes recetas, responde la consulta del usuario: "{query}"
    
    Recetas relevantes:
    {chr(10).join(recipe_summaries)}
    
    Proporciona una respuesta útil y específica basada en estas recetas. Si es apropiado, recomienda una receta específica y explica por qué.
    """
    
    # Generate response using OpenAI
    response = client.responses.create(
        model="gpt-4.1",
        input=prompt
    )

    return response.output_text

# %%
query = "¿Dame la receta de la Sopa de pollo?"
response = seeker(query)
print("Respuesta de ChatGPT:")
print(response)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Respuesta de ChatGPT:
# ¡Claro! Basándome en las recetas proporcionadas, la mejor receta que corresponde a "Sopa de pollo" es el **Caldo de Pollo**, que es una sopa clásica de pollo mexicana, llena de sabor y vegetales. Aquí tienes la receta detallada:
#
# ---
#
# ## Receta de Sopa de Pollo (Caldo de Pollo)
#
# ### Ingredientes
# - 5 libras de muslos o piernas de pollo
# - 2 galones de agua
# - 2 cucharadas de ajo picado
# - 2 cucharadas de sal
# - 1 cucharada de ajo en polvo
# - 1 cubo de consomé de pollo
# - 4 zanahorias grandes, peladas y cortadas en trozos grandes
# - 4 papas grandes, peladas y cortadas en trozos grandes
# - 4 calabacitas, cortadas en trozos grandes
# - 1 chayote, cortado en trozos grandes
# - 1 cebolla blanca grande, cortada en trozos grandes
# - ½ manojo de cilantro fresco, picado
#
# ### Instrucciones
# 1. **Prepara los ingredientes:** Junta todos los ingredientes y corta las verduras en trozos grandes.
# 2. **Cocina el pollo:** Coloca los muslos o piernas de pollo en una olla grande. Vierte el agua sobre el pollo. Añade el ajo picado, sal y ajo en polvo. Tapa y lleva a ebullición a fuego alto.
# 3. **Hierve y cocina a fuego lento:** Cuando comience a hervir, reduce el fuego y deja cocinar a fuego lento hasta que la carne del pollo se desprenda del hueso, aproximadamente 1 a 2 horas.
# 4. **Agrega las verduras y condimentos:** Incorpora el cubo de consomé de pollo y revuelve hasta que se disuelva. Añade las zanahorias, papas, calabacitas, chayote y cebolla.
# 5. **Cocina las verduras:** Reduce el fuego a medio-bajo y cocina a fuego lento hasta que las papas y zanahorias estén tiernas, aproximadamente 45 minutos a 1 hora.
# 6. **Agrega el cilantro:** Añade el cilantro picado y deja cocinar 5 minutos más.
# 7. **Sirve caliente y disfruta:** Sirve el caldo en tazones hondos, asegurándote de repartir tanto el caldo como las piezas de pollo y verduras.
#
# > **Consejo:** Puedes acompañar la sopa con arroz blanco o agregar elote (mazorca de maíz), según tu gusto.
#
# ---
#
# ### ¿Por qué te la recomiendo?
#
# El **Caldo de Pollo** es la versión más clásica y popular de la sopa de pollo en México. Es reconfortante, nutritiva, y puedes adaptarla a los ingredientes y vegetales que tengas a la mano. Además, preparar el caldo con piezas enteras de pollo le aporta un sabor profundo y auténtico.
#
# ---
#
# **Imagen de referencia:**
# ![Caldo de Pollo](https://www.allrecipes.com/thmb/ocohCvTN9iJolTzz6Igbt-JtgLA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/231097-caldo-de-pollo-ddmfs-Beauty1x2-1986447967964eb5a526906b0062962b.jpg)
#
# ---
#
# ¿Te gustaría una versión más sencilla o tienes una duda sobre la receta? ¡Estoy aquí para ayudarte!
